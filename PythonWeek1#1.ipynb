# %%
# !git clone https://github.com/DongguneKim/Assignment.git
#Q1:

print("Hello World!!!")

#Q2:

print(type(6/2))
print(type(6//2))

#Q3:

Total_Min = 1300
Total_Hour = int(Total_Min/60)

Total_Time_Representing="Hour: "+str(Total_Hour)+" Min: "+str(Total_Min%60)
print(Total_Time_Representing)
# Out:
# fatal: destination path 'Assignment' already exists and is not an empty directory.
# Hello World!!!
# <class 'float'>
# <class 'int'>
# Hour: 21 Min: 40

# %%
#Q2:

print(type(6/2))
print(type(6//2))
# Out:
# <class 'float'>
# <class 'int'>

# %%
#Q3:

Total_Min = 1300
Total_Hour = int(Total_Min/60)

Total_Time_Representing="Hour: "+str(Total_Hour)+" Min: "+str(Total_Min%60)
print(Total_Time_Representing)
# Out:
# Hour: 21 Min: 40
